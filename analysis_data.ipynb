# %%
import pandas as  pd 
pd_data = pd.read_csv('./df_data/2025-08-30_chat_data.csv')
print(len(pd_data))
pd_data.info()
# Out:
# 4384
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4384 entries, 0 to 4383
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   chat_id            23 non-null     object
#  1   chat_user_id       4384 non-null   object
#  2   chat_title         4384 non-null   object
#  3   chat_model         4384 non-null   object
#  4   last_chat_model    4384 non-null   object
#  5   chat_created_at    4384 non-null   object
#  6   chat_updated_at    4384 non-null   object
#  7   user_name          4384 non-null   object
#  8   role               4384 non-null   object
#  9   model              0 non-null      float64
#  10  models             4384 non-null   object
#  11  message_id         4384 non-null   object
#  12  parentId           1622 non-null   object
#  13  last_child_id      4384 non-null   object
#  14  childrenIds        4384 non-null   object
# ...

# %%
import pandas as  pd 
feedback_pd_data = pd.read_csv('./df_data/2025-08-30_feedback_data.csv')
print(len(feedback_pd_data))
feedback_pd_data.info()
# Out:
# 995
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   feedback_id     995 non-null    object
#  1   user_id         995 non-null    object
#  2   user_name       995 non-null    object
#  3   good_or_bad     995 non-null    object
#  4   rating_score    972 non-null    float64
#  5   rating_comment  215 non-null    object
#  6   query           994 non-null    object
#  7   answer          994 non-null    object
#  8   model           995 non-null    object
#  9   message_id      995 non-null    object
#  10  parentId        995 non-null    object
#  11  created_at      995 non-null    object
# dtypes: float64(1), object(11)
# memory usage: 93.4+ KB

# %%
feedback_pd_data.groupby('message_id').size().sort_values(ascending=False).head(10)
# Out:
# message_id
# 0ce02c89-3574-47a5-83f8-ac0a9e90742f    19
# b4854133-7aec-4959-9c44-7a1bd542a134    11
# 8f0f0d41-6df8-4963-aca6-44235cbfdad7     2
# d009fac1-6e4b-4cbd-86c4-d8d5e223a955     2
# 6fd1ddb1-b4f3-46a9-81ac-34a90a97890d     2
# b4f180a2-6c42-4893-abfc-ddc9d25fa8c1     1
# b13b0b5a-4c2d-4d34-a16c-be33cbd08431     1
# ae095233-7062-44c3-b449-aea3154a74e1     1
# b639c2ab-0ec3-4b45-94d2-346f33eea914     1
# ae1f5cab-f471-4885-bcf0-2260d295609c     1
# dtype: int64

# %%
feedback_pd_data[feedback_pd_data['message_id'] == '0ce02c89-3574-47a5-83f8-ac0a9e90742f']
# Out:
#                               feedback_id  \
# 238  01898e25-c2e2-4b60-b15e-484c8be8784e
# 239  43d44399-e39c-4cd3-9435-09efe45a547c
# 240  f751a68f-d744-4ae6-bf24-5f07c176d3fa
# 241  afb8d677-0dc9-45e7-afa4-c02a9ac8f58b
# 242  f91a0fe0-c72a-40eb-b138-fd1e58eaf6c2
# 243  384d9024-db3b-4dae-b2da-6dd347235eda
# 244  2644bd26-5be3-4c6f-8a95-fafca304451d
# 245  8efed222-4917-40d3-80a6-a3e98f0932d4
# 246  3fe14773-375c-4da4-8568-06a38e53ffbd
# 247  759e3e9d-8c1c-479a-a98b-7a3439c6dd34
# 248  fb7ca559-e858-4e6a-9654-7a9993ca82dc
# 249  2b497f64-bfac-4fad-8598-cd3b9f2581de
# 250  d742ee52-4736-4b05-8ea9-3b0ff4b25716
# 251  17495f3d-d474-4c39-bf72-f1ba9cda10a2
# 252  a06ecf27-b790-4e7c-bb1b-b2b6d5dfc95a
# 253  fb435ac6-f227-4bfa-969f-80fe8ed1a19b
# 254  8fad5b07-e6f8-417d-be85-0ee787653459
# 255  4a424e6c-2500-484e-8ccc-51f2c483397e
# 256  483204bc-54e1-43cf-a8f8-ee7431adecfd
#
#                                   user_id    user_name good_or_bad  \
# ...

# %%
feedback_pd_data.drop_duplicates(subset=['message_id'],keep='last', inplace=True)
len(feedback_pd_data)
# Out:
# 964

# %%
feedback_pd_data_message_id = feedback_pd_data.message_id.unique().tolist()
len(feedback_pd_data_message_id)
# Out:
# 964

# %%
normal_pd_data_ = pd_data[~pd_data.answer_message_id.isin(feedback_pd_data_message_id)]
normal_pd_data_0725 = normal_pd_data_[normal_pd_data_.created_at>"2025-07-25 00:00:00"]
len(normal_pd_data_),len(normal_pd_data_0725)
# Out:
# (3432, 1150)

# %%
len(pd_data[pd_data.created_at>"2025-07-25 00:00:00"])
# Out:
# 1461

# %%
len(pd_data)
# Out:
# 4384
